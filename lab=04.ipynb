# %% [markdown]
# <a href="https://colab.research.google.com/github/Goutham345/p-and-s/blob/main/lab%3D04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
def load_data(filepath="/content/titanic_dataset_250-7.csv"):
  df=pd.read_csv(filepath)
  return df
df=load_data()
print(df.head())
print(df.info())
print(df.describe())
plt.figure(figsize=(8, 6))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Distribution of Age Among Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
#    Passenger ID  Age  Gender Class  Survived    Fare     Embarked  \
# 0             1   52    Male   2nd         1   25.90   Queenstown
# 1             2   15  Female   2nd         0   92.25  Southampton
# 2             3   72    Male   1st         0  108.86   Queenstown
# 3             4   61  Female   3rd         0   52.28   Queenstown
# 4             5   21    Male   1st         1   57.50  Southampton
#
#    Siblings/Spouses Aboard  Parents/Children Aboard
# 0                        0                        2
# 1                        4                        3
# 2                        1                        0
# 3                        3                        0
# 4                        1                        3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
# ...

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Age'], bins=20, kde=True, color='blue')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age among Passengers')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=df)
plt.title('Relationship Between Fare and Age')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.legend(title='Survival Status')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('titanic_dataset_250-7.csv')
df.head()
# Out:
#    Passenger ID  Age  Gender Class  Survived    Fare     Embarked  \
# 0             1   52    Male   2nd         1   25.90   Queenstown
# 1             2   15  Female   2nd         0   92.25  Southampton
# 2             3   72    Male   1st         0  108.86   Queenstown
# 3             4   61  Female   3rd         0   52.28   Queenstown
# 4             5   21    Male   1st         1   57.50  Southampton
#
#    Siblings/Spouses Aboard  Parents/Children Aboard
# 0                        0                        2
# 1                        4                        3
# 2                        1                        0
# 3                        3                        0
# 4                        1                        3

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Age', y='Fare', hue='Survived', palette={0: 'red', 1: 'pink'})
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatterplot of Fare vs Age')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Class', palette='pastel')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.title('Number of Passengers in Each Class')
plt.show()
# Out:
# <ipython-input-15-6624d6b9449b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Class', palette='pastel')

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Class', data=df)
plt.title('Number of Passengers by Pclass')
plt.xlabel('Class')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Class', hue='Survived', data=df)
plt.title('Survival Rates by Pclass')
plt.xlabel('Class')
plt.ylabel('Count')
plt.legend(title='Survival Status')
plt.show()

# %%
common_age_group = df['Age'].mode()[0]
print(f'The most common age group observed in the dataset is {common_age_group} years.')

# Checking the trend between Age and Fare
correlation = df[['Age', 'Fare']].corr().iloc[0,1]
print(f'Correlation between Age and Fare: {correlation:.2f}')
if abs(correlation) > 0.2:
    print('There is a weak relationship between age and fare paid.')
else:
    print('There is no strong visible trend between age and fare paid.')

# Identifying the class with the highest passengers
highest_class = df['Class'].value_counts().idxmax()
print(f'The passenger class with the highest number of passengers is Class {highest_class}.')

# Survival variation across passenger classes
survival_rates = df.groupby('Class')['Survived'].mean()
print('Survival rates per class:\n', survival_rates)
# Out:
# The most common age group observed in the dataset is 62 years.
# Correlation between Age and Fare: -0.15
# There is no strong visible trend between age and fare paid.
# The passenger class with the highest number of passengers is Class 1st.
# Survival rates per class:
#  Class
# 1st    0.460784
# 2nd    0.533333
# 3rd    0.383562
# Name: Survived, dtype: float64
